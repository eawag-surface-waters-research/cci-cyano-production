# %%
import sys
import os
sys.path.append(os.path.abspath('../scripts'))
from visualization import PhenologyVisualization
from functions import datenum_to_datetime
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import pandas as pd

# %%
lakeid = 9 # 212, 339
i , j = 44,550

# %%
# version 3.1
pc_phenology_path_v3 = f"D:\\lakecci_data\\raw\\v3.1\\phenology\\phycocyanin\\{lakeid}.nc"
pc_extract_path_v3 = f"D:\\lakecci_data\\raw\\v3.1\\extract\\phycocyanin\\{lakeid}.nc"

chl_phenology_path_v3 = f"D:\\lakecci_data\\raw\\v3.1\\phenology\\chla\\{lakeid}.nc"
chl_extract_path_v3 = f"D:\\lakecci_data\\raw\\v3.1\\extract\\chla\\{lakeid}.nc"

# %%
PhenologyVisualization.set_shapefile_path(r"C:\Users\schelian\Downloads\lakes_cci_v2.1.0_shp\shapefile\lakescci_v2.1.0_data-availability.shp")

# %%
# load classes
# phyco_v3 = PhenologyVisualization(pc_extract_path_v3, pc_phenology_path_v3)
chla_v3 = PhenologyVisualization(chl_extract_path_v3, chl_phenology_path_v3)

# %% [markdown]
# ## Make a legend

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5))
legend_elements = [Line2D([0], [0], marker='o', color='k', label='QA: Good',
                          markerfacecolor='green', markersize=10),
                   Line2D([0], [0], marker='o', color='k', label='QA: Fair',
                          markerfacecolor='orange', markersize=10),
                   Line2D([0], [0], marker='o', color='k', label='QA: Poor',
                          markerfacecolor='red', markersize=10),
                    Line2D([0], [0], marker='^', color='w', label='mid green-up',
                          markerfacecolor='mediumseagreen', markersize=10),
                    Line2D([0], [0], marker='v', color='w', label='mid green-down',
                          markerfacecolor='darkgreen', markersize=10),]

ax.legend(handles=legend_elements,ncols=2, loc = 'center')

# %%
img = plt.imshow(np.array([[0,1]]),cmap='RdYlBu')
img.set_visible(False)
cbar = plt.colorbar(orientation='vertical')
cbar.set_label( label='correlation',size=15)
cbar.ax.tick_params(labelsize=15)

# %% [markdown]
# ## Lake-wide plotting

# %%
fig, ax = plt.subplots(1,1,figsize=(15,5))
phyco_v3.metric_map(phyco_v3.correlation_scores([(0, 9999)]),'correlation',fig,ax,'RdYlBu')
# Out:
# c:\Users\schelian\cci-cyano-production\scripts\visualization.py:559: UserWarning: correlation need to be calculated. Depending on the lake size this may take a while.
#   warnings.warn(f"{metric_name} need to be calculated. Depending on the lake size this may take a while.")

# %% [markdown]
# ## Standard times series plots

# %%
plt.rcParams["axes.labelsize"] = 16

plt.rcParams["xtick.labelsize"] = 16
plt.rcParams["ytick.labelsize"] = 16

# %%
from matplotlib.lines import Line2D

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(15,5))

chla_v3.single_plot(i,j, ax, aggregation=False,start=2003, end= 2012)
ax.collections[0].set(color = 'grey')
ax.collections[0].set_sizes([30])
# chla_v3.single_plot(155,306, ax, aggregation=False, start=2003,end= 2012)
# ax.collections[-5].set(color = 'orangered',sizes=[30])
ax.set_ylabel('chla [ug/L]')
for txt in ax.texts:
    txt.remove()
ax.get_legend().remove()
ax.set_xlim(pd.to_datetime("01-01-2003", format= "%d-%m-%Y"), pd.to_datetime("01-01-2012", format= "%d-%m-%Y"))
ax.set_ylim(-0.5,6)
ax.set_title("")
for p in ax.patches:
    p.remove()
ax.axhline(color='k')
# Out:
# c:\Users\schelian\cci-cyano-production\scripts\visualization.py:2267: Warning: Negative Troughs(s) in time period 2003-2012
#   warnings.warn(f"Negative Troughs(s) in time period {start}-{end}", Warning)

# %%
fig, axs = plt.subplots(1,2, figsize = (20,8))

chla_v3.split_plot(ax0 = axs[0], ax1=axs[1],latitude = i,longitude = j, aggregation=False,end0 = 2012,start1 = 2016)
axs[0].set_title("")
axs[1].set_title("")
# axs[0].set_ylim(0,2)
axs[1].set_ylim(-1,125)


axs[0].texts[0].set_fontsize(12)
axs[1].texts[0].set_fontsize(12)
# Out:
# c:\Users\schelian\cci-cyano-production\scripts\visualization.py:1959: Warning: Negative Troughs(s) in time period 0-2012
#   warnings.warn(f"Negative Troughs(s) in time period {start}-{end}", Warning)

# %%
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(1,1,figsize=(8,4))

chla_v3.single_plot(i,j, ax, aggregation=False)

ax.get_legend().remove()
ax.texts[0].remove()
plt.title('')
plt.ylabel('chl-a (ug/L)')
ax.set_xlim(pd.to_datetime("01-11-2003", format= "%d-%m-%Y"), pd.to_datetime("01-03-2005", format= "%d-%m-%Y"));
ax.xaxis.set_major_formatter(
    mdates.ConciseDateFormatter(ax.xaxis.get_major_locator()))

plt.ylim(-0.5,5)
# Out:
# c:\Users\schelian\cci-cyano-production\scripts\visualization.py:1959: Warning: Negative Troughs(s) in time period 0-9999
#   warnings.warn(f"Negative Troughs(s) in time period {start}-{end}", Warning)
# (-0.5, 5.0)

# %%
# %matplotlib inline
fig, ax = plt.subplots(1,1,figsize=(18,5))

chla_v3.extrema_plot(i,j,ax,)
ax.set_xlim(pd.to_datetime("01-01-2003", format= "%d-%m-%Y"), pd.to_datetime("01-01-2012", format= "%d-%m-%Y"))
ax.set_ylim(top=6)
ax.set_ylabel('chla [ug/L]')
ax.set_title("")
plt.legend(fontsize=12,loc='upper right')

# %% [markdown]
# ## Basic map

# %%
chla_v3.valid_coords
# Out:
# [(2, 461),
#  (2, 462),
#  (2, 463),
#  (2, 464),
#  (2, 465),
#  (2, 466),
#  (2, 467),
#  (2, 468),
#  (2, 469),
#  (2, 470),
#  (2, 471),
#  (2, 472),
#  (2, 473),
#  (3, 451),
#  (3, 453),
#  (3, 454),
#  (3, 455),
#  (3, 459),
#  (3, 460),
#  (3, 461),
#  (3, 462),
#  (3, 463),
#  (3, 464),
#  (3, 465),
#  (3, 466),
#  (3, 467),
#  (3, 468),
#  (3, 469),
#  (3, 470),
#  (3, 471),
#  (3, 472),
#  (3, 473),
#  (3, 474),
#  (4, 449),
#  (4, 450),
#  (4, 451),
#  (4, 452),
#  (4, 453),
#  (4, 454),
#  (4, 455),
#  (4, 456),
#  (4, 457),
#  (4, 458),
#  (4, 459),
#  (4, 460),
#  (4, 461),
#  (4, 462),
#  (4, 463),
#  (4, 464),
#  (4, 465),
#  (4, 466),
#  (4, 467),
#  (4, 468),
#  (20, 363),
#  (20, 364),
#  (20, 365),
#  (20, 366),
#  (20, 367),
#  (20, 368),
#  (20, 369),
#  (20, 370),
#  (20, 371),
#  (20, 372),
#  (20, 373),
#  (20, 439),
#  (20, 440),
#  (20, 441),
#  (20, 442),
#  (20, 443),
#  (20, 444),
#  (20, 445),
#  (20, 446),
#  (20, 447),
#  (20, 448),
#  (20, 449),
#  (20, 450),
#  (20, 451),
#  (20, 452),
#  (20, 453),
#  (20, 454),
#  (20, 455),
#  (20, 456),
#  (20, 457),
#  (20, 458),
#  (20, 459),
#  (20, 460),
#  (20, 461),
#  (20, 462),
#  (20, 463),
#  (20, 464),
#  (20, 465),
#  (20, 466),
#  (20, 467),
#  (20, 468),
#  (20, 469),
#  (20, 470),
#  (20, 471),
#  (20, 472),
#  (20, 473),
#  (20, 474),
#  (20, 475),
#  (20, 476),
#  (20, 477),
#  (20, 478),
#  (20, 479),
#  (20, 480),
#  (20, 481),
#  (20, 482),
#  (20, 483),
#  (20, 484),
#  (20, 485),
#  (20, 486),
#  (20, 487),
#  (20, 488),
#  (20, 489),
#  (20, 490),
#  (20, 491),
#  (20, 492),
#  (20, 493),
#  (20, 494),
#  (20, 495),
#  (20, 496),
#  (20, 497),
#  (20, 498),
#  (20, 499),
#  (20, 500),
#  (20, 501),
#  (20, 502),
#  (20, 503),
#  (20, 504),
#  (20, 505),
#  (20, 506),
#  (20, 507),
#  (20, 508),
#  (20, 509),
#  (20, 510),
#  (20, 511),
#  (20, 512),
#  (21, 354),
#  (21, 355),
#  (21, 356),
#  (21, 357),
#  (21, 358),
#  (21, 359),
#  (21, 360),
#  (21, 361),
#  (21, 362),
#  (21, 363),
#  (21, 364),
#  (21, 365),
#  (21, 366),
#  (21, 367),
#  (21, 368),
#  (21, 369),
#  (21, 370),
#  (21, 440),
#  (21, 441),
#  (21, 442),
#  (21, 443),
#  (21, 444),
#  (21, 445),
#  (21, 446),
#  (21, 447),
#  (21, 448),
#  (21, 449),
#  (21, 450),
#  (21, 451),
#  (21, 452),
#  (21, 453),
#  (21, 454),
#  (21, 455),
#  (21, 456),
#  (21, 457),
#  (21, 462),
#  (21, 463),
#  (21, 464),
#  (21, 465),
#  (21, 466),
#  (21, 467),
#  (21, 468),
#  (21, 469),
#  (21, 470),
#  (21, 471),
#  (21, 472),
#  (21, 473),
#  ...]

# %%
# %matplotlib inline
fig, ax = plt.subplots(1,1,figsize=(15,5))
chla_v3.pixel_map(,ax=ax)

# %%
fig, axs = plt.subplots(1,2, figsize = (20,8))
cmap = 'RdYlBu'
colorbar_extent = [0,1]
# phyco_v3.metric_map(phyco_v3.correlation_scores([(0, 2012)]),'correlation', fig, axs[0],cmap, colorbar_extent= colorbar_extent)
phyco_v3.metric_map(phyco_v3.correlation_scores([(2016,9999)]),'correlation', fig, axs[1],cmap, colorbar_extent= colorbar_extent)

fig.axes[-1].remove()
fig.axes[-1].remove()

axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[0].set_ylabel('')
axs[1].set_ylabel('')

axs[1].set_yticklabels([])
axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[0].set_title('')
axs[1].set_title('')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[147], line 5
#       3 colorbar_extent = [0,1]
#       4 # phyco_v3.metric_map(phyco_v3.correlation_scores([(0, 2012)]),'correlation', fig, axs[0],cmap, colorbar_extent= colorbar_extent)
# ----> 5 phyco_v3.metric_map(phyco_v3.correlation_scores([(2016,9999)]),'correlation', fig, axs[1],cmap, colorbar_extent= colorbar_extent)
#       7 fig.axes[-1].remove()
#       8 fig.axes[-1].remove()
#
# File c:\Users\schelian\cci-cyano-production\scripts\visualization.py:858, in PhenologyVisualization.metric_map(self, metric_scores, metric_str, fig, ax, colormap, colorbar_extent)
#     855 buffered_geom = self.shrink_geometry_by_1km(geom)
#     856 buffered_geom_prepared = prep(buffered_geom)
# --> 858 map_data, extent = grab_metrics(self.e_path, metric_scores, buffered_geom_prepared)
#     860 im = plot_map_data(colormap, map_data, extent, ax, cmap_extent=colorbar_extent)
#     861 plot_lake_outline(geometry=geom, ax=ax)
#
# File c:\Users\schelian\cci-cyano-production\scripts\functions.py:143, in grab_metrics(e_path, metric_scores, buffered_geom_prep)
#     141 for (i, j), r2 in metric_scores.items():
#     142     lon = lons[j]
# --> 143     lat = lats[i]
#     144     if buffered_geom_prep.contains(Point(lon, lat)):
#     145         map_data[i, j] = r2
#
# File c:\Users\schelian\AppData\Local\miniforge3\envs\esaclimate\Lib\site-packages\numpy\ma\core.py:3305, in MaskedArray.__getitem__(self, indx)
#    3295 """
#    3296 x.__getitem__(y) <==> x[y]
#    3297
#    3298 Return the item described by i, as a masked array.
#    3299
#    3300 """
#    3301 # We could directly use ndarray.__getitem__ on self.
#    3302 # But then we would have to modify __array_finalize__ to prevent the
#    3303 # mask of being reshaped if it hasn't been set up properly yet
#    3304 # So it's easier to stick to the current version
# -> 3305 dout = self.data[indx]
#    3306 _mask = self._mask
#    3308 def _is_scalar(m):
#
# IndexError: index 37 is out of bounds for axis 0 with size 37

# %% [markdown]
# ## Zoom in of peaks
#
# with optional date highlighting
#
# Used to compare against Mortimer's POLYMER processing

# %%
fig, ax = plt.subplots(1,1,figsize=(15,5))

phyco_v3.single_plot(7,3, ax, aggregation=True, start=2018, end= 2018)
ax.set_xlim(pd.to_datetime("01-04-2018", format= "%d-%m-%Y"), pd.to_datetime("21-04-2018", format= "%d-%m-%Y"))
ax.set_ylim(0,4)

ax.collections[0].set(color = 'black')
ax.collections[0].set_sizes([30])
ax.axvline(x=pd.to_datetime("08-04-2018", format= "%d-%m-%Y"),alpha = 0.4, c= "red")
ax.axvline(x=pd.to_datetime("13-04-2018", format= "%d-%m-%Y"),alpha = 0.7, c = "black")
# ax.axvline(x=pd.to_datetime("09-01-2022", format= "%d-%m-%Y"),alpha = 0.4, c= "purple")
# ax.axvline(x=pd.to_datetime("28-01-2022", format= "%d-%m-%Y"),alpha = 0.4, c= "purple")

# %% [markdown]
# ## Single day plots

# %%
manual_date = pd.to_datetime("06-11-2002", format= "%d-%m-%Y")
print(manual_date)
phyco_v3.single_day_map(manual_date)
# Out:
# 2002-11-06 00:00:00

# %%
phyco_v3.single_day_map(series.idxmax())

# %%
series = phyco_v3.load_pixel_data(i, j)
for d in np.arange(-15,15):
    try:
        phyco_v3.single_day_map(manual_date+pd.Timedelta(d,"D"))
    except Exception:
        print(str(d)+": no data")
# Out:
# -15: no data
# -14: no data
# -13: no data
# -12: no data
# -11: no data
# -10: no data
# -9: no data
# -8: no data
# -6: no data
# -5: no data
# -4: no data
# -3: no data
# -2: no data
# 1: no data
# 3: no data
# 4: no data
# 5: no data
# 6: no data
# 7: no data
# 8: no data
# 9: no data
# 10: no data
# 11: no data
# 12: no data
# 13: no data
# 14: no data

# %% [markdown]
# ## Hard-coded Lake Superior plot. Do not delete.

# %%
bad_pixel_series = chla_v3.load_pixel_data(158,668)
bad_date = chla_v3._extracted_globals['t_all'][datenum_to_datetime(chla_v3._extracted_globals['t_all']) ==bad_pixel_series.idxmax()]
np.argwhere(datenum_to_datetime(chla_v3._extracted_globals['t_all']) ==bad_pixel_series.idxmax())
# Out:
# array([[258]])

# %%
g = chla_v3._load_extracted_globals()
with netCDF4.Dataset(chla_v3.e_path) as nc:
                                values = np.array(nc.variables[g["variable"]][258, :, :])
                                qa     = np.array(nc.variables[g["qa"]][258, :, :])

mask = (values != -9999) & (qa == 0)

# %%
lake_row = chla_v3.geom[chla_v3.geom["id"] == lakeid]
geom = lake_row.geometry.iloc[0]
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
with netCDF4.Dataset(chla_v3.e_path) as nc:
        summary = np.array(nc.variables["summary"][:, :])
        lats = nc.variables["lat"][:]
        lons = nc.variables["lon"][:]
        map_data = np.where(mask, values, np.nan)
        cmap = "winter"
        im = ax.imshow(map_data, cmap=cmap, aspect="auto", origin="lower", extent=[lons.min(), lons.max(), lats.min(), lats.max()])
        for poly in geom.geoms:
                        x, y = poly.exterior.xy
                        label = "Lake Outline" if not label else None
                        ax.plot(x, y, color="black", linewidth=1, label = label)
                        label = True
fig.colorbar(im,orientation='vertical',label='chla (ug/L)')
plt.xticks([])
plt.yticks([])
plt.title(datenum_to_datetime(bad_date).astype(str)[0])
# Out:
# Text(0.5, 1.0, '2003-08-25 00:00:00+00:00')

# %%
combo_df = pd.concat([good_pixel_series,bad_pixel_series],axis=1).dropna(axis=0)
combo_df['year']= combo_df.index.year
combo_df.plot(kind='scatter',x=0,y=1,c='year',cmap='Paired')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
bad_pixel_series.index
# Out:
# DatetimeIndex(['2002-05-22 00:00:00+00:00', '2002-05-24 00:00:00+00:00',
#                '2002-06-03 00:00:00+00:00', '2002-06-22 00:00:00+00:00',
#                '2002-07-01 00:00:00+00:00', '2002-07-02 00:00:00+00:00',
#                '2002-07-11 00:00:00+00:00', '2002-07-18 00:00:00+00:00',
#                '2002-07-24 00:00:00+00:00', '2002-08-06 00:00:00+00:00',
#                ...
#                '2023-09-24 00:00:00+00:00', '2023-09-27 00:00:00+00:00',
#                '2023-09-28 00:00:00+00:00', '2023-09-29 00:00:00+00:00',
#                '2023-10-02 00:00:00+00:00', '2023-10-03 00:00:00+00:00',
#                '2023-10-05 00:00:00+00:00', '2023-11-15 00:00:00+00:00',
#                '2023-11-20 00:00:00+00:00', '2023-12-29 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=1090, freq=None)

# %% [markdown]
# ## Sensor comparison plots

# %%
phyco_series = phyco_v3.load_pixel_data(i,j)
chla_series = chla_v3.load_pixel_data(i,j)
meris_sensor = chla_series.index.year < 2013

# %%
def sensor_str_from_year(year_val):
    if year_val < 2013:
        return "meris"
    elif year_val < 2016:
        return "modis"
    elif year_val >=2016:
        return "S3"

# %%
df_to_plot = pd.concat([chla_series,phyco_series],axis=1)
df_to_plot.columns = ['chla','phyco']
df_to_plot['year'] = df_to_plot.index.year
df_to_plot['meris_period'] = df_to_plot['year'] < 2013
df_to_plot['sensor_period'] = df_to_plot['year'].apply(sensor_str_from_year)

# %%
default_cmap = sns.color_palette('tab10',3)
tri_order_cmap = [default_cmap[i] for i in [0,2,1]]
tri_order_cmap
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (1.0, 0.4980392156862745, 0.054901960784313725)]

# %%
sns.set_context("talk")
g = sns.JointGrid(df_to_plot, x= "chla",y="phyco",hue="sensor_period",hue_order=["meris","modis","S3"],height=6,palette=tri_order_cmap)
g.plot_joint(sns.kdeplot,levels=[0.005,0.01,0.1,0.5])
g.plot_marginals(sns.boxplot)

# %%
# Set up the figure
f, ax = plt.subplots(figsize=(8, 8))
sns.kdeplot(data=df_to_plot,x='chla',y='phyco',hue='sensor_period',levels=10,thresh=0.005)
plt.xlabel("chl-a v3 (ug/L)")
plt.ylabel("PC (ug/L)")
plt.axhline(20,c='k',linestyle='--')
# sns.move_legend(ax,'upper left')
# plt.xlim(right=150)
# plt.ylim(bottom=20)

# %%
chla_meris = df_to_plot.loc[df_to_plot['sensor_period']=='meris','chla']
chla_s3 = df_to_plot.loc[df_to_plot['sensor_period']=='S3','chla']

pd.concat([chla_meris.describe(), chla_s3.describe()],axis=1)
# Out:
#              chla        chla
# count  738.000000  934.000000
# mean   113.130989   66.210037
# std     80.591293   52.322433
# min      0.001744    0.029178
# 25%    104.099106   41.925774
# 50%    116.103210   61.845787
# 75%    132.531784   83.651108
# max    967.275391  387.925323

# %% [markdown]
# ## Panel of annual plots

# %%
year_vals = list(df_to_plot.index.year.unique())

# %%
fig, ax = plt.subplots(1,1,figsize=(15,5))

chla_v3.single_plot(i,j, ax, aggregation=False,start=2006, end= 2007)

# %%
np.arange(2002,2004)
# Out:
# array([2002, 2003])

# %%
chla_v3.single_years_plot(i, j, np.arange(2011,2013), 4, 1, "R2")
